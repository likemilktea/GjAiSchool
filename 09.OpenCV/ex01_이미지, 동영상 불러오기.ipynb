# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.8.0.74-cp37-abi3-win_amd64.whl (38.1 MB)
#                                               0.0/38.1 MB ? eta -:--:--
#                                               0.2/38.1 MB 3.1 MB/s eta 0:00:13
#                                               0.3/38.1 MB 3.3 MB/s eta 0:00:12
#                                               0.4/38.1 MB 3.6 MB/s eta 0:00:11
#                                               0.5/38.1 MB 3.0 MB/s eta 0:00:13
#                                               0.7/38.1 MB 3.0 MB/s eta 0:00:13
#      -                                        1.1/38.1 MB 3.8 MB/s eta 0:00:10
#      -                                        1.2/38.1 MB 3.9 MB/s eta 0:00:10
#      -                                        1.4/38.1 MB 3.8 MB/s eta 0:00:10
#      -                                        1.8/38.1 MB 4.2 MB/s eta 0:00:09
#      --                                       2.1/38.1 MB 4.5 MB/s eta 0:00:08
#      --                                       2.4/38.1 MB 4.7 MB/s eta 0:00:08
#      --                                       2.7/38.1 MB 5.0 MB/s eta 0:00:08
#      ---                                      2.9/38.1 MB 4.8 MB/s eta 0:00:08
#      ---                                      3.3/38.1 MB 5.0 MB/s eta 0:00:07
#      ---                                      3.6/38.1 MB 5.2 MB/s eta 0:00:07
#      ----                                     4.1/38.1 MB 5.5 MB/s eta 0:00:07
#      ----                                     4.5/38.1 MB 5.7 MB/s eta 0:00:06
#      -----                                    4.8/38.1 MB 5.8 MB/s eta 0:00:06
#      -----                                    5.4/38.1 MB 6.0 MB/s eta 0:00:06
#      -----                                    5.6/38.1 MB 5.9 MB/s eta 0:00:06
#      ------                                   6.1/38.1 MB 6.2 MB/s eta 0:00:06
#      ------                                   6.4/38.1 MB 6.2 MB/s eta 0:00:06
#      ------                                   6.6/38.1 MB 6.1 MB/s eta 0:00:06
#      -------                                  7.0/38.1 MB 6.2 MB/s eta 0:00:06
#      -------                                  7.1/38.1 MB 6.2 MB/s eta 0:00:05
#      -------                                  7.4/38.1 MB 6.1 MB/s eta 0:00:05
#      -------                                  7.4/38.1 MB 5.9 MB/s eta 0:00:06
#      --------                                 8.0/38.1 MB 6.1 MB/s eta 0:00:05
#      --------                                 8.3/38.1 MB 6.1 MB/s eta 0:00:05
#      ---------                                8.7/38.1 MB 6.2 MB/s eta 0:00:05
#      ---------                                9.1/38.1 MB 6.3 MB/s eta 0:00:05
#      ---------                                9.4/38.1 MB 6.2 MB/s eta 0:00:05
#      ---------                                9.5/38.1 MB 6.2 MB/s eta 0:00:05
#      ----------                               9.7/38.1 MB 6.1 MB/s eta 0:00:05
#      ----------                               9.7/38.1 MB 5.9 MB/s eta 0:00:05
#      ----------                               10.1/38.1 MB 6.1 MB/s eta 0:00:05
#      ----------                               10.4/38.1 MB 6.1 MB/s eta 0:00:05
#      -----------                              10.7/38.1 MB 6.3 MB/s eta 0:00:05
#      -----------                              11.0/38.1 MB 6.4 MB/s eta 0:00:05
#      -----------                              11.1/38.1 MB 6.4 MB/s eta 0:00:05
#      -----------                              11.4/38.1 MB 6.4 MB/s eta 0:00:05
#      ------------                             11.6/38.1 MB 6.4 MB/s eta 0:00:05
#      ------------                             11.8/38.1 MB 6.4 MB/s eta 0:00:05
#      ------------                             12.1/38.1 MB 6.4 MB/s eta 0:00:05
#      ------------                             12.3/38.1 MB 6.2 MB/s eta 0:00:05
#      -------------                            12.6/38.1 MB 6.2 MB/s eta 0:00:05
#      -------------                            12.8/38.1 MB 6.2 MB/s eta 0:00:05
#      -------------                            13.0/38.1 MB 6.2 MB/s eta 0:00:05
#      -------------                            13.1/38.1 MB 6.1 MB/s eta 0:00:05
#      --------------                           13.5/38.1 MB 6.0 MB/s eta 0:00:05
#      --------------                           13.8/38.1 MB 5.9 MB/s eta 0:00:05
#      --------------                           14.0/38.1 MB 5.8 MB/s eta 0:00:05
#      ---------------                          14.4/38.1 MB 5.8 MB/s eta 0:00:05
#      ---------------                          14.6/38.1 MB 5.7 MB/s eta 0:00:05
#      ---------------                          15.0/38.1 MB 5.6 MB/s eta 0:00:05
#      ----------------                         15.2/38.1 MB 5.6 MB/s eta 0:00:05
#      ----------------                         15.4/38.1 MB 5.5 MB/s eta 0:00:05
#      ----------------                         15.6/38.1 MB 5.5 MB/s eta 0:00:05
#      ----------------                         15.9/38.1 MB 5.5 MB/s eta 0:00:05
#      -----------------                        16.2/38.1 MB 5.4 MB/s eta 0:00:05
#      -----------------                        16.3/38.1 MB 5.3 MB/s eta 0:00:05
#      -----------------                        16.6/38.1 MB 5.3 MB/s eta 0:00:05
#      -----------------                        16.8/38.1 MB 5.3 MB/s eta 0:00:04
#      -----------------                        17.0/38.1 MB 5.3 MB/s eta 0:00:04
#      -----------------                        17.1/38.1 MB 5.2 MB/s eta 0:00:05
#      ------------------                       17.4/38.1 MB 5.2 MB/s eta 0:00:04
#      ------------------                       17.6/38.1 MB 5.2 MB/s eta 0:00:04
#      ------------------                       17.8/38.1 MB 5.2 MB/s eta 0:00:04
#      ------------------                       18.0/38.1 MB 5.1 MB/s eta 0:00:04
#      -------------------                      18.1/38.1 MB 5.1 MB/s eta 0:00:04
#      -------------------                      18.3/38.1 MB 5.0 MB/s eta 0:00:04
#      -------------------                      18.5/38.1 MB 5.0 MB/s eta 0:00:04
#      -------------------                      18.7/38.1 MB 4.9 MB/s eta 0:00:04
#      -------------------                      18.9/38.1 MB 4.9 MB/s eta 0:00:04
#      --------------------                     19.0/38.1 MB 4.8 MB/s eta 0:00:04
#      --------------------                     19.3/38.1 MB 4.7 MB/s eta 0:00:04
#      --------------------                     19.4/38.1 MB 4.7 MB/s eta 0:00:04
#      --------------------                     19.5/38.1 MB 4.7 MB/s eta 0:00:04
#      --------------------                     19.7/38.1 MB 4.7 MB/s eta 0:00:04
#      --------------------                     19.9/38.1 MB 4.6 MB/s eta 0:00:04
#      ---------------------                    20.0/38.1 MB 4.7 MB/s eta 0:00:04
#      ---------------------                    20.3/38.1 MB 4.6 MB/s eta 0:00:04
#      ---------------------                    20.3/38.1 MB 4.6 MB/s eta 0:00:04
#      ---------------------                    20.5/38.1 MB 4.5 MB/s eta 0:00:04
#      ---------------------                    20.7/38.1 MB 4.5 MB/s eta 0:00:04
#      ---------------------                    20.9/38.1 MB 4.5 MB/s eta 0:00:04
#      ----------------------                   21.1/38.1 MB 4.4 MB/s eta 0:00:04
#      ----------------------                   21.3/38.1 MB 4.4 MB/s eta 0:00:04
#      ----------------------                   21.5/38.1 MB 4.4 MB/s eta 0:00:04
#      ----------------------                   21.7/38.1 MB 4.3 MB/s eta 0:00:04
#      ----------------------                   21.8/38.1 MB 4.3 MB/s eta 0:00:04
#      -----------------------                  22.0/38.1 MB 4.3 MB/s eta 0:00:04
#      -----------------------                  22.3/38.1 MB 4.3 MB/s eta 0:00:04
#      -----------------------                  22.6/38.1 MB 4.3 MB/s eta 0:00:04
#      -----------------------                  22.8/38.1 MB 4.2 MB/s eta 0:00:04
#      ------------------------                 23.0/38.1 MB 4.2 MB/s eta 0:00:04
#      ------------------------                 23.2/38.1 MB 4.2 MB/s eta 0:00:04
#      ------------------------                 23.3/38.1 MB 4.3 MB/s eta 0:00:04
#      ------------------------                 23.5/38.1 MB 4.2 MB/s eta 0:00:04
#      ------------------------                 23.7/38.1 MB 4.1 MB/s eta 0:00:04
#      -------------------------                23.9/38.1 MB 4.1 MB/s eta 0:00:04
#      -------------------------                24.0/38.1 MB 4.1 MB/s eta 0:00:04
#      -------------------------                24.1/38.1 MB 4.1 MB/s eta 0:00:04
#      -------------------------                24.2/38.1 MB 4.0 MB/s eta 0:00:04
#      -------------------------                24.4/38.1 MB 3.9 MB/s eta 0:00:04
#      -------------------------                24.5/38.1 MB 3.9 MB/s eta 0:00:04
#      -------------------------                24.7/38.1 MB 3.9 MB/s eta 0:00:04
#      --------------------------               24.9/38.1 MB 3.9 MB/s eta 0:00:04
#      --------------------------               25.0/38.1 MB 3.9 MB/s eta 0:00:04
#      --------------------------               25.2/38.1 MB 3.9 MB/s eta 0:00:04
#      --------------------------               25.4/38.1 MB 3.8 MB/s eta 0:00:04
#      --------------------------               25.6/38.1 MB 3.8 MB/s eta 0:00:04
#      ---------------------------              25.8/38.1 MB 3.8 MB/s eta 0:00:04
#      ---------------------------              26.0/38.1 MB 3.8 MB/s eta 0:00:04
#      ---------------------------              26.3/38.1 MB 3.8 MB/s eta 0:00:04
#      ---------------------------              26.4/38.1 MB 3.7 MB/s eta 0:00:04
#      ----------------------------             26.7/38.1 MB 3.7 MB/s eta 0:00:04
#      ----------------------------             26.8/38.1 MB 3.7 MB/s eta 0:00:03
#      ----------------------------             27.0/38.1 MB 3.7 MB/s eta 0:00:03
#      ----------------------------             27.2/38.1 MB 3.7 MB/s eta 0:00:03
#      ----------------------------             27.3/38.1 MB 3.6 MB/s eta 0:00:03
#      ----------------------------             27.5/38.1 MB 3.7 MB/s eta 0:00:03
#      -----------------------------            27.7/38.1 MB 3.7 MB/s eta 0:00:03
#      -----------------------------            27.9/38.1 MB 3.6 MB/s eta 0:00:03
#      -----------------------------            28.1/38.1 MB 3.6 MB/s eta 0:00:03
#      -----------------------------            28.3/38.1 MB 3.6 MB/s eta 0:00:03
#      -----------------------------            28.5/38.1 MB 3.7 MB/s eta 0:00:03
#      ------------------------------           28.7/38.1 MB 3.7 MB/s eta 0:00:03
#      ------------------------------           28.9/38.1 MB 3.6 MB/s eta 0:00:03
#      ------------------------------           29.0/38.1 MB 3.6 MB/s eta 0:00:03
#      ------------------------------           29.2/38.1 MB 3.6 MB/s eta 0:00:03
#      ------------------------------           29.2/38.1 MB 3.6 MB/s eta 0:00:03
#      ------------------------------           29.4/38.1 MB 3.6 MB/s eta 0:00:03
#      -------------------------------          29.6/38.1 MB 3.6 MB/s eta 0:00:03
#      -------------------------------          29.7/38.1 MB 3.6 MB/s eta 0:00:03
#      -------------------------------          29.8/38.1 MB 3.6 MB/s eta 0:00:03
#      -------------------------------          30.1/38.1 MB 3.6 MB/s eta 0:00:03
#      -------------------------------          30.3/38.1 MB 3.6 MB/s eta 0:00:03
#      --------------------------------         30.4/38.1 MB 3.6 MB/s eta 0:00:03
#      --------------------------------         30.6/38.1 MB 3.6 MB/s eta 0:00:03
#      --------------------------------         30.7/38.1 MB 3.6 MB/s eta 0:00:03
#      --------------------------------         30.8/38.1 MB 3.6 MB/s eta 0:00:03
#      --------------------------------         30.9/38.1 MB 3.5 MB/s eta 0:00:03
#      --------------------------------         31.1/38.1 MB 3.5 MB/s eta 0:00:02
#      --------------------------------         31.1/38.1 MB 3.5 MB/s eta 0:00:02
#      --------------------------------         31.2/38.1 MB 3.4 MB/s eta 0:00:02
#      --------------------------------         31.3/38.1 MB 3.4 MB/s eta 0:00:02
#      ---------------------------------        31.4/38.1 MB 3.4 MB/s eta 0:00:02
#      ---------------------------------        31.6/38.1 MB 3.4 MB/s eta 0:00:02
#      ---------------------------------        31.8/38.1 MB 3.4 MB/s eta 0:00:02
#      ---------------------------------        31.9/38.1 MB 3.4 MB/s eta 0:00:02
#      ---------------------------------        32.1/38.1 MB 3.4 MB/s eta 0:00:02
#      ---------------------------------        32.2/38.1 MB 3.4 MB/s eta 0:00:02
#      ---------------------------------        32.3/38.1 MB 3.4 MB/s eta 0:00:02
#      ----------------------------------       32.4/38.1 MB 3.4 MB/s eta 0:00:02
#      ----------------------------------       32.6/38.1 MB 3.3 MB/s eta 0:00:02
#      ----------------------------------       32.7/38.1 MB 3.4 MB/s eta 0:00:02
#      ----------------------------------       33.1/38.1 MB 3.4 MB/s eta 0:00:02
#      ----------------------------------       33.2/38.1 MB 3.4 MB/s eta 0:00:02
#      -----------------------------------      33.4/38.1 MB 3.4 MB/s eta 0:00:02
#      -----------------------------------      33.7/38.1 MB 3.4 MB/s eta 0:00:02
#      -----------------------------------      33.9/38.1 MB 3.4 MB/s eta 0:00:02
#      -----------------------------------      34.1/38.1 MB 3.4 MB/s eta 0:00:02
#      -----------------------------------      34.2/38.1 MB 3.5 MB/s eta 0:00:02
#      ------------------------------------     34.4/38.1 MB 3.5 MB/s eta 0:00:02
#      ------------------------------------     34.4/38.1 MB 3.5 MB/s eta 0:00:02
#      ------------------------------------     34.5/38.1 MB 3.4 MB/s eta 0:00:02
#      ------------------------------------     34.6/38.1 MB 3.4 MB/s eta 0:00:02
#      ------------------------------------     34.7/38.1 MB 3.4 MB/s eta 0:00:01
#      ------------------------------------     34.9/38.1 MB 3.4 MB/s eta 0:00:01
#      ------------------------------------     35.1/38.1 MB 3.4 MB/s eta 0:00:01
#      -------------------------------------    35.3/38.1 MB 3.4 MB/s eta 0:00:01
#      -------------------------------------    35.4/38.1 MB 3.4 MB/s eta 0:00:01
#      -------------------------------------    35.4/38.1 MB 3.4 MB/s eta 0:00:01
#      -------------------------------------    35.6/38.1 MB 3.4 MB/s eta 0:00:01
#      -------------------------------------    35.8/38.1 MB 3.3 MB/s eta 0:00:01
#      -------------------------------------    35.9/38.1 MB 3.4 MB/s eta 0:00:01
#      -------------------------------------    36.1/38.1 MB 3.3 MB/s eta 0:00:01
#      --------------------------------------   36.3/38.1 MB 3.3 MB/s eta 0:00:01
#      --------------------------------------   36.5/38.1 MB 3.3 MB/s eta 0:00:01
#      --------------------------------------   36.8/38.1 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  37.1/38.1 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------  37.4/38.1 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------  37.6/38.1 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------  37.9/38.1 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------  38.1/38.1 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------- 38.1/38.1 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in c:\users\gjaischool1\anaconda3\envs\machine\lib\site-packages (from opencv-python) (1.24.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.0.74

# %%
# 크기 800*1000 이하
# 얼굴이 있는 사진

# %%
# # opencv > cv2
# import cv2
# # 이미지 불러오기
# img = cv2.imread('./data/funny.jpeg')
# # 윈도우에 이미지 띄우기
# cv2.imshow('img',img)
# # 키보드로부터 키 입력을 기다리는 시간
# # 0 = 계속 대기, 코드가 cv2.waitKey(0)에 머무른 상태로 넘어가지 않는다.
# # 1000ms = 1초 : 1초동안 기다렸다가 키 입력 없으면 넘어감
# # 키를 입력하면 바로 넘어감
# cv2.waitKey(1000)
# # opencv로 열어놓은 윈도우창 닫기
# cv2.destroyAllWindows()

# %%
# 이미지를 흑백사진으로 불러오기

import cv2
img = cv2.imread('./data/funny.jpeg', cv2.IMREAD_GRAYSCALE)
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 불러온 이미지 흑백사진으로 만들기
img = cv2.imread('./data/funny.jpeg')
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imshow('img',img)
cv2.imshow('gray_img',gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# RGB : 빛의 3원색
# Red Green, Blue : 모일수록 하얗게 됨
# 이미지를 불러올 때는 파란계열, 초록계열, 빨간계열 3가지를 따로 불러옴
img.shape
# Out:
# (222, 221, 3)

# %%
# 동영상 : 초당 많은 사진을 연속적으로 보기
# 보통 : 초당 30장의 사진으로 이루어져 있음
# 일반인 : 초당 12~15장이면 동영상으로 인식
# 전문가 : 초당 15~20장이면 동영상으로 인식

# %%
# 캠으로부터 동영상을 가져오기
import cv2
# 비디오 불러오기
# 0 : 컴퓨터에 연결된 카메라
# 동영상 경로 적어주면 동영상에 연결
cap = cv2.VideoCapture(0)
cnt = 0

# 녹화 설정
fps = 30.0 # 녹화할 프레임 수
width = int(cap.get(3)) # 녹화할 영상의 가로 크기(픽셀)
height = int(cap.get(4)) # 녹화할 영상의 세로 크기(픽셀)

# 코덱 설정
# avi > DIVX
# mp4 > MPEG
fcc = cv2.VideoWriter_fourcc(*'MPEG')

# 동영상 설정
out = cv2.VideoWriter('video.mp4',fcc,fps,(width,height) )
record = False

#초당 30장의 사진 인식
while True: 
    # 연결해놓은 카메라에서 사진 가져오기
    ret, frame = cap.read() # 한번 실행할 때마다 한장씩의 사진 가져옴
    # ret : 불러오기 성공하면 True, 실패하면 False
    # frame : 불러온 사진 이미지 값
    if not ret:
        print("비디오 읽기 실패 또는 비디오 모두 읽음")
        cap.release() # 연결해놓은 카메라 or 동영상 닫기
        cv2.destroyAllWindows() # 윈도우에 열어놓은 창 닫기
        break # 더이상 사진을 불러오지 않아도 되므로 while문 종료
    
       
    # 이미지를 불러왔을 때
    cv2.imshow('video', frame)
    k = cv2.waitKey(33) # 33ms마다 사진 넘긱기 = 1초에 약 30장의 사진을 보내주고 있다.
    
    # 종료 버튼 만들기
    # 1(!) 누르면 종료하기
    if k == 49: # 1은 아스키코드로 49를 가지고 있음
        print('동영상을 종료합니다')
        cap.release() # 카메라 닫기
        cv2.destroyAllWindows() # 윈도우 창 닫기
        break # while문 종료
    
    # 캡쳐(2)
    if k == 50:
        cnt+=1
        cv2.imwrite(f'./data/cap{cnt}.png',frame, params = [cv2.IMWRITE_PNG_COMPRESSION, 0])
        print('동영상을 캡쳐합니다')
        
    # 녹화시작(3)
    if k == 51:
        record=True
        print('동영상 녹화를 시작합니다')
    
    # 3번을 누르고 나서 실행
    if record:
        out.write(frame)
        
    # 녹화종료(4)
    if k ==52:
        out.release()
        print('동영상 녹화를 종료합니다')
# Out:
# 동영상을 녹화합니다
# 동영상 녹화를 종료합니다
# 동영상을 종료합니다
