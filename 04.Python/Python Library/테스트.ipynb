# %%
import requests
import xml.dom.minidom

url = 'http://openapi.seoul.go.kr:8088/52735373497a657238304d75724642/xml/tbLnOpendataRtmsV/1/5'

response = requests.get(url)
xml_str = response.content.decode('utf-8')

# %%
dom = xml.dom.minidom.parseString(xml_str)
pretty_xml = dom.toprettyxml(indent="    ")
print(pretty_xml)
# Out:
# <?xml version="1.0" ?>
# <tbLnOpendataRtmsV>
#
#
#     <list_total_count>2673484</list_total_count>
#
#
#     <RESULT>
#
#
#         <CODE>INFO-000</CODE>
#
#
#         <MESSAGE>정상 처리되었습니다</MESSAGE>
#
#
#     </RESULT>
#
#
#     <row>
#
#
#         <ACC_YEAR>2023</ACC_YEAR>
#
#
#         <SGG_CD>11170</SGG_CD>
#
#
#         <SGG_NM>용산구</SGG_NM>
#
#
#         <BJDONG_CD>11700</BJDONG_CD>
#
#
#         <BJDONG_NM>원효로3가</BJDONG_NM>
#
#
#         <LAND_GBN>1</LAND_GBN>
#
#
#         <LAND_GBN_NM>대지</LAND_GBN_NM>
#
#
#         <BONBEON>0051</BONBEON>
#
#
#         <BUBEON>0037</BUBEON>
#
#
#         <BLDG_NM>e테크밸리</BLDG_NM>
#
#
#         <DEAL_YMD>20230718</DEAL_YMD>
#
#
#         <OBJ_AMT>15000</OBJ_AMT>
#
#
#         <BLDG_AREA>32</BLDG_AREA>
#
#
#         <TOT_AREA>44.310000</TOT_AREA>
#
#
#         <FLOOR>15</FLOOR>
#
#
#         <RIGHT_GBN/>
#
#
#         <CNTL_YMD/>
#
#
#         <BUILD_YEAR>2003</BUILD_YEAR>
#
#
#         <HOUSE_TYPE>오피스텔</HOUSE_TYPE>
#
#
#         <REQ_GBN>중개거래</REQ_GBN>
#
#
#         <RDEALER_LAWDNM>서울 용산구</RDEALER_LAWDNM>
#
#
#     </row>
#
#
#     <row>
#
#
#         <ACC_YEAR>2023</ACC_YEAR>
#
#
#         <SGG_CD>11545</SGG_CD>
#
#
#         <SGG_NM>금천구</SGG_NM>
#
#
#         <BJDONG_CD>10200</BJDONG_CD>
#
#
#         <BJDONG_NM>독산동</BJDONG_NM>
#
#
#         <LAND_GBN>1</LAND_GBN>
#
#
#         <LAND_GBN_NM>대지</LAND_GBN_NM>
#
#
#         <BONBEON>0908</BONBEON>
#
#
#         <BUBEON>0003</BUBEON>
#
#
#         <BLDG_NM>미성빌라</BLDG_NM>
#
#
#         <DEAL_YMD>20230718</DEAL_YMD>
#
#
#         <OBJ_AMT>27500</OBJ_AMT>
#
#
#         <BLDG_AREA>70.46</BLDG_AREA>
#
#
#         <TOT_AREA>34.750000</TOT_AREA>
#
#
#         <FLOOR>2</FLOOR>
#
#
#         <RIGHT_GBN/>
#
#
#         <CNTL_YMD/>
#
#
#         <BUILD_YEAR>2003</BUILD_YEAR>
#
#
#         <HOUSE_TYPE>연립다세대</HOUSE_TYPE>
#
#
#         <REQ_GBN>중개거래</REQ_GBN>
#
#
#         <RDEALER_LAWDNM>서울 금천구</RDEALER_LAWDNM>
#
#
#     </row>
#
#
#     <row>
#
#
#         <ACC_YEAR>2023</ACC_YEAR>
#
#
#         <SGG_CD>11500</SGG_CD>
#
#
#         <SGG_NM>강서구</SGG_NM>
#
#
#         <BJDONG_CD>10300</BJDONG_CD>
#
#
#         <BJDONG_NM>화곡동</BJDONG_NM>
#
#
#         <LAND_GBN>1</LAND_GBN>
#
#
#         <LAND_GBN_NM>대지</LAND_GBN_NM>
#
#
#         <BONBEON>0046</BONBEON>
#
#
#         <BUBEON>0216</BUBEON>
#
#
#         <BLDG_NM>삼성빌라</BLDG_NM>
#
#
#         <DEAL_YMD>20230718</DEAL_YMD>
#
#
#         <OBJ_AMT>15200</OBJ_AMT>
#
#
#         <BLDG_AREA>38.3</BLDG_AREA>
#
#
#         <TOT_AREA>17.490000</TOT_AREA>
#
#
#         <FLOOR>3</FLOOR>
#
#
#         <RIGHT_GBN/>
#
#
#         <CNTL_YMD/>
#
#
#         <BUILD_YEAR>1993</BUILD_YEAR>
#
#
#         <HOUSE_TYPE>연립다세대</HOUSE_TYPE>
#
#
#         <REQ_GBN>중개거래</REQ_GBN>
#
#
#         <RDEALER_LAWDNM>서울 강서구</RDEALER_LAWDNM>
#
#
#     </row>
#
#
#     <row>
#
#
#         <ACC_YEAR>2023</ACC_YEAR>
#
#
#         <SGG_CD>11260</SGG_CD>
#
#
#         <SGG_NM>중랑구</SGG_NM>
#
#
#         <BJDONG_CD>10100</BJDONG_CD>
#
#
#         <BJDONG_NM>면목동</BJDONG_NM>
#
#
#         <LAND_GBN>1</LAND_GBN>
#
#
#         <LAND_GBN_NM>대지</LAND_GBN_NM>
#
#
#         <BONBEON>0538</BONBEON>
#
#
#         <BUBEON>0000</BUBEON>
#
#
#         <BLDG_NM>신영</BLDG_NM>
#
#
#         <DEAL_YMD>20230718</DEAL_YMD>
#
#
#         <OBJ_AMT>10200</OBJ_AMT>
#
#
#         <BLDG_AREA>14.43</BLDG_AREA>
#
#
#         <TOT_AREA>0.000000</TOT_AREA>
#
#
#         <FLOOR>5</FLOOR>
#
#
#         <RIGHT_GBN/>
#
#
#         <CNTL_YMD/>
#
#
#         <BUILD_YEAR>2013</BUILD_YEAR>
#
#
#         <HOUSE_TYPE>아파트</HOUSE_TYPE>
#
#
#         <REQ_GBN>직거래</REQ_GBN>
#
#
#         <RDEALER_LAWDNM/>
#
#
#     </row>
#
#
#     <row>
#
#
#         <ACC_YEAR>2023</ACC_YEAR>
#
#
#         <SGG_CD>11410</SGG_CD>
#
#
#         <SGG_NM>서대문구</SGG_NM>
#
#
#         <BJDONG_CD>11700</BJDONG_CD>
#
#
#         <BJDONG_NM>연희동</BJDONG_NM>
#
#
#         <LAND_GBN>1</LAND_GBN>
#
#
#         <LAND_GBN_NM>대지</LAND_GBN_NM>
#
#
#         <BONBEON>0136</BONBEON>
#
#
#         <BUBEON>0030</BUBEON>
#
#
#         <BLDG_NM>연희휴니스빌</BLDG_NM>
#
#
#         <DEAL_YMD>20230718</DEAL_YMD>
#
#
#         <OBJ_AMT>28500</OBJ_AMT>
#
#
#         <BLDG_AREA>45.49</BLDG_AREA>
#
#
#         <TOT_AREA>27.400000</TOT_AREA>
#
#
#         <FLOOR>2</FLOOR>
#
#
#         <RIGHT_GBN/>
#
#
#         <CNTL_YMD/>
#
#
#         <BUILD_YEAR>2016</BUILD_YEAR>
#
#
#         <HOUSE_TYPE>연립다세대</HOUSE_TYPE>
#
#
#         <REQ_GBN>중개거래</REQ_GBN>
#
#
#         <RDEALER_LAWDNM>서울 서대문구</RDEALER_LAWDNM>
#
#
#     </row>
#
#
# </tbLnOpendataRtmsV>
