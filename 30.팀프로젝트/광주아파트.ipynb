# %%
import pandas as pd

# %%
data = pd.read_csv("06~23 광주아파트(매매).csv", encoding="EUC-KR")
data
# Out:
# C:\Users\gjaischool1\AppData\Local\Temp\ipykernel_2176\1910380689.py:1: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("06~23 광주아파트(매매).csv", encoding="EUC-KR")
#                   시군구      번지    본번  부번      단지명   전용면적(㎡)    계약년월  계약일  \
# 0       광주광역시 광산구 도산동  1138-2  1138   2      대덕1   59.3100  202303   18
# 1       광주광역시 광산구 도산동     790   790   0  대주피오레1차   84.9800  202302    7
# 2       광주광역시 광산구 도산동     790   790   0  대주피오레1차   84.9800  202305   31
# 3       광주광역시 광산구 도산동     820   820   0  대주피오레2차   84.7575  202305    9
# 4       광주광역시 광산구 도산동     820   820   0  대주피오레2차   84.7575  202305   13
# ...               ...     ...   ...  ..      ...       ...     ...  ...
# 425074   광주광역시 서구 화정동     440   440   0     화정우미  115.1850  200611   10
# 425075   광주광역시 서구 화정동     440   440   0     화정우미   84.8300  200611   27
# 425076   광주광역시 서구 화정동     440   440   0     화정우미   59.8300  200611   30
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425079 entries, 0 to 425078
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   시군구       425079 non-null  object
#  1   번지        425079 non-null  object
#  2   본번        425079 non-null  int64
#  3   부번        425079 non-null  int64
#  4   단지명       425079 non-null  object
#  5   전용면적(㎡)   425079 non-null  float64
#  6   계약년월      425079 non-null  int64
#  7   계약일       425079 non-null  int64
#  8   거래금액(만원)  425079 non-null  object
#  9   층         425079 non-null  int64
#  10  건축년도      425079 non-null  int64
#  11  도로명       425079 non-null  object
#  12  해제사유발생일   3417 non-null    float64
#  13  거래유형      75324 non-null   object
#  14  중개사소재지    75324 non-null   object
# dtypes: float64(2), int64(6), object(7)
# memory usage: 48.6+ MB

# %%
data = data.drop('해제사유발생일',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data = data.drop('해제사유발생일',axis=1)
#
# File c:\Users\gjaischool1\anaconda3\envs\machine\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %%
data = data.drop('거래유형',axis=1)
data = data.drop('중개사소재지',axis=1)
data = data.drop('도로명',axis=1)
data = data.drop('거래금액(만원)',axis=1)
data = data.drop('번지',axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425079 entries, 0 to 425078
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   시군구      425079 non-null  object
#  1   본번       425079 non-null  int64
#  2   부번       425079 non-null  int64
#  3   단지명      425079 non-null  object
#  4   전용면적(㎡)  425079 non-null  float64
#  5   계약년월     425079 non-null  int64
#  6   계약일      425079 non-null  int64
#  7   층        425079 non-null  int64
#  8   건축년도     425079 non-null  int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 29.2+ MB
